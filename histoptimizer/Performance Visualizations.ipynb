# %%
from histoptimizer.benchmark import partitioner_pivot
import pandas as pd
import plotly.graph_objects as go
import plotly

# %%
r = pd.read_json('e:/src/histoptimizer/sample_report.json.bz2')
traces = []
colorscales = ['Blugrn', 'Darkmint', 'Matter', 'Purpor']
for p in ('dynamic_numba', 'cuda_2', 'cuda_3'):
    traces.append(partitioner_pivot(r, p))

# %%
fig = go.Figure(go.Surface(
    x = traces[0].columns,
    y = traces[0].index,
    z = traces[0],
    colorscale = colorscales[0]))
for i in range(1, len(traces)):
    t = traces[i]
    fig.add_trace(
        go.Surface(
            x = t.columns,
            y = t.index,
            z = t,
            opacity=0.5,
            colorscale = colorscales[i]
        ),

    )
fig.update_layout(
        title = "Execution time in seconds",
        scene = {
            "xaxis": {"ticktext": [str(n) for n in traces[0].columns.tolist()],
                      "tickvals": traces[0].columns.tolist()},
            "yaxis": {"ticktext": [str(n) for n in traces[0].index],
                      "tickvals": traces[0].index.tolist()},
            "zaxis": {"nticks": 10},
            "xaxis_title": "Buckets",
            "yaxis_title": "Items",
            "zaxis_title": "Seconds",
            'camera_eye': {"x": 1.2, "y": 1.2, "z": 0.5},
            "aspectratio": {"x": 1, "y": 1, "z": 0.5}
        })
plotly.offline.plot(fig, filename='retailplot.html')
fig.show()
# Out:
# <div>                            <div id="f7a09ddb-566c-4b19-be79-8a8e30edef3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7a09ddb-566c-4b19-be79-8a8e30edef3b")) {                    Plotly.newPlot(                        "f7a09ddb-566c-4b19-be79-8a8e30edef3b",                        [{"colorscale": [[0.0, "rgb(196, 230, 195)"], [0.16666666666666666, "rgb(150, 210, 164)"], [0.3333333333333333, "rgb(109, 188, 144)"], [0.5, "rgb(77, 162, 132)"], [0.6666666666666666, "rgb(54, 135, 122)"], [0.8333333333333334, "rgb(38, 107, 110)"], [1.0, "rgb(29, 79, 96)"]], "type": "surface", "x": [10, 30, 50, 70, 90], "y": [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600], "z": [[0.00050002335, 0.000749647625, 0.001244962225, 0.00174951555, 0.0015113353750000002], [0.0012549758, 0.002007424825, 0.003008186825, 0.003250181675, 0.0039915442499999995], [0.0020081401, 0.003236591825, 0.004764139650000001, 0.0070074796500000005, 0.00774782895], [0.0030080080250000003, 0.005512773975, 0.007742345350000001, 0.010253667825, 0.012506663800000001], [0.0040078759, 0.008229553700000001, 0.01124978065, 0.014734566225, 0.018756508850000003], [0.005501568325, 0.01076358555, 0.015249967574999999, 0.020244896400000004, 0.025